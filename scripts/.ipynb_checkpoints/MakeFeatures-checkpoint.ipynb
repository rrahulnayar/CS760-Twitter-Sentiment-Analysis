# %%
import numpy as np
import pandas as pd
import re
from sklearn import preprocessing

dataF = "G:/edu/sem2/760/proj/CS760-Twitter-Sentiment-Analysis/data/"
allF = dataF+'train_utf8.csv'
samF = dataF+'sample.csv'
featF = dataF+'svmAllFeatures.csv'

# %%
dt = pd.read_csv(samF)
NUM_FEATURES = 6

negWords = re.compile(
    r'(not|no|nor|neither|(n\'*t)|false|wrong)\b'
,re.I)

posWords = re.compile(
    r'yes|true|correct'
,re.I)

wasteWords =re.compile(
    r'\b(the|a|an|as|be|am|is|are|was|were|has|have|had|\
    at|from|to|in|under|before|after|near|far|away|for|and|\
    that|them|there|their|they|his|her|hers|him|it|you|your|yours)\b'
, re.I)

#allow - &
badpunc = re.compile(
    r'\.|\_|\:|\'|\`|\"|\~|\!|\@|\#|\$|\%|\^|\*|\(|\)|\+|\=|\{|\}|\[|\]|\
    \;|\<|\>|\,|\?|\/|\\|\|')

#tweet character length
def F0(txt):
    return len(txt)

#tweet word length
def F1(txt):
    return len(txt.split())

#tweet character length w/o punc
def F2(txt):
    return len(re.sub(badpunc,'',txt))

#word length w/o atricles and prepositions
def F3(txt):
    print(re.sub(wasteWords,'',txt).split())
    return len(re.sub(wasteWords,'',txt).split())

#count of neg words
def F4(txt):
    return len(re.findall(negWords,txt))

#count of pos words
def F5(txt):
    return len(re.findall(posWords,txt))

# %%
#string corrections
def modify(txt):
    txt = txt.strip()
    txt = txt.replace('&quot;',"'")
    txt = txt.replace('&amp;','&')
    txt = txt.replace('&lt;','<')
    txt = txt.replace('&gt;','>')
    txt = re.sub(r'\s+',' ',txt)
    return txt

# %%
labels = dt['Sentiment'].map(lambda x: 'Y' if x==1 else 'N')

# %%
#Loop of features
feats = {str(i):eval('F'+str(i)) for i in range(NUM_FEATURES)}
#correct all strings
tweets = dt['SentimentText'].map(modify)
tweets.to_csv('../data/tweetsModified.csv')
#Build all features
features = {i:tweets.map(f) for i,f in feats.items()}#ma
# Out:
# ['@cpuclub', 'what', 'hell', 'mike', 'died????', 'Fuck', 'man', 'I', 'always', 'played', 'that', 'guy', 'denver.', 'Such', 'generous', 'kind', 'dude.', 'Rip']
# ['@crystalchappell', "I'm", 'totally', 'jealous', 'here', '!', 'What', 'do', 'I', '2', 'do', '2', 'get', 'some', 'CC', 'Tweets', 'sent', 'my', 'way', "Don't", 'forget', 'peeps', 'back', 'NYC..']
# ['@Cadistra', 'If', 'turns', 'out', 'not', 'Celiac', '(I', 'hope!),', 'might', 'check', 'IBS,', 'which', 'some', 'of', 'same', 'symptoms.', 'Easier', 'cook', ',', 'too.']
# ['@adammshankman', "'male", "movie'?", 'Freudian', 'slip?', 'hee', 'hee']
# [',', 'hello', 'twitterers!', 'nothing', 'do!']
# ["'Never", 'Let', 'fear', 'of', 'striking', 'keep', 'playing', "game.'-Cinderella", 'Story.']
# ['@ahj', 'How', 'do', 'see', 'photos', '?', 'do', 'i', 'go', '?']
# ['@corbthfrog', 'OMG,', 'that', 'truly', 'most', 'wonderful', 'name', 'I', 'heard', 'kitten', 'long', 'time']
# ['@ave77', 'sure', 'visit', 'http://www.MedanKu.com']
# ['...', 'writing', 'essay', 'about', 'monkeys.', 'Best.', 'Punishment.', 'EVAH!']
# ['...hope', 'this', "doesn't", 'set', 'J', 'up', 'fear', 'of', 'needles', 'life.']
# ['@AgentSullivan', 'I', 'know.', "I'll", 'stay', 'with', 'weekend', 'slowly', 'move', 'back', 'my', 'place.', "'s", 'going', 'really', 'quiet', 'without', '.']
# ['#dontyouhate', 'not', 'being', 'around', 'people', 'love/care', 'about']
# ['@ChantiParnell', "Don't", 'make', 'me', 'jelouse']
# ['@chambernic', 'haha', 'yay!!!!!', 'cute', 'shades', 'btw']
# ['@biancaconsunji', 'excellent', 'copies', 'I', 'love', 'this', 'kind', 'of', 'resurrecting', 'things', 'on', 'pictures!', 'Looking', 'forward', 'more', 'future!']
# ['@BabyboomerGeek', 'What', 'do', 'think', 'best', 'twitter', 'tool?', 'I', 'like', 'tweet', 'later.', 'http://www.tweetlater.com/86234.html']
# ['@bsneed23', 'LOL!', 'Lucky', '...', 'I', "don't", 'know', 'why', 'I', "can't", 'sleep', 'I', 'up', 'at', 'like', '8', "I'm", 'gonna', 'so', 'tired.']
# ['I', 'sick', '@posty', 'today.', 'He', 'headache,', 'cough,', 'sore', 'throat.', 'He', 'curled', 'up', 'on', 'couch.']
# ['good', 'i', 'hope', 'not', 'my', 'love', 'because', 'im', 'love', 'with', 'u', 'dont', 'wanna', 'lose', 'u']
# ['@adamasity_bebe', 'I', 'miss', 'u', 'too', 'see', 'u', 'on', 'monday']
# ['@cececov', 'girl.......', "'re", 'at', 'again', 'when', 'get', 'computer', 'remove', 'em', 'can', 'do', 'mine', 'too?!?']
# ['@andrewwoodhouse', 'Yep.', 'Radio']
# ['@comeagainjen', 'I', 'come', 'MIchigan']
# ['@_wendy_r_', 'we', 'bought', 'tix', 'see', 'tomorrow,', 'WITH', '3D', 'glasses!', "we'll", 'take', 'sequel', 'that', 'prior', 'photo']
# ['@aza1234', 'welcome,', 'thanks', '!']
# ['@AmandaMallard', "i'm", 'not', 'at', "chaseton's", 'either', 'please', "don't", 'die,', 'my', 'heart', 'will', 'really', 'sad']
# ['@BabeNatasha', 'i', 'dunno...', 'i', 'only', 'use', 'app', 'version']
# ["'Maybe", "'ll", 'send', 'me', "bbm's'", 'Haha', 'lauren', "can't", 'believe', 'last', 'episode', 'today']
# ['@amoir', '*huggle*', 'Night', 'babe,', 'stay', 'awesome!']
# ['@bellewalk', 'now', 'i', 'really', 'want', 'see', 'live.']
# ['@amyxstftk', 'bahaha', 'i', 'loook', 'like', 'kung', 'fu', 'panda', 'when', 'i', 'wake', 'up', 'morning.']
# ['*Shorty', 'dog', 'go', 'out!', '8', 'sigh,', "I'll", 'brb']
# ['@andrevr', 'thanks', 'penguin']
# ['@BradinBuffalo', 'haha', 'I', 'passed', 'out', 'I', 'got', 'that', 'invitation']
# ['@CSI_PrintChick', 'Sorry', 'we', 'missed', "ya'll", 'last', 'night', '--', 'safe', 'trip', 'home.', "I'm", 'lobby,', 'come', 'see', 'me...??']
# ['@arielswimalott', 'Yes,', 'super', 'sweet', 'movie.', 'Sounds', 'like', "'re", 'too?!', 'Madly', 'love', 'that', '.']
# ['@BoyceAvenue', 'Oh', 'em', 'gee.', 'coming', 'AZ!', '(Totally', 'Rhymed)', 'I', "can't", 'wait', 'see', 'guys', 'again!', 'Hmm..', 'Perhaps', 'maybe', 'another', 'shout', 'out?Lol']
# ['@aneehan', 'what', 'written?', '&&', 'thanks', 'love,', 'based', 'off', 'challenges', 'page.', 'I', 'mean,', 'like', 'during', 'season', '3']
# ['@amm_amii', 'finally', 'u', 'change', 'ur', 'background', 'ammsss..', 'congrats!']
# ['@columbiacity', 'craving', 'Umi', 'Sushi', '&', 'thought', 'of', '.', 'been', 'back', 'since', '@MoniGuzman,', '&', 'I', '@', 'same', 'time?', 'Love', 'that', 'place.']
# ['@_anahs', ';-)', 'CALL', 'MEEEEEEEEEEE,', "I'M", 'BORED!!!']
# ['@BigAssBadger', 'Tell', 'Sapphy', 'I', 'said', 'Hi', '!!!', 'Just', 'trying', 'get', 'ready', 'builders', 'coming', 'on', 'Thursday-', '5', 'weeks', 'of', 'total', 'disruption', 'due']
# ['@abbieupton', 'Thanks', 'sweetie', '-', 'hey', 'if', 'smile', 'at', '@clairemacdonald', 'might', 'birthday', 'treats', '!!!!']
# ['(watching', 'some', 'tv', 'show', 'with', 'scene', 'carnival..)', 'Come', 'Think', 'Of', ',', 'Carnivals', 'Creepy!', 'Especially', 'House', 'Of', 'Mirrors', 'At', 'Night!']
# ['@bishab', 'Thanks', 'boo.', 'heading', 'Jamaica']
# ['@AboveCommon', 'awww', 'man', 'thats', 'spam']
# ['@algonquinrt', 'Bwahahhahah!', 'That', 'so', 'true...', 'I', 'heard', 'ice', 'cream', 'sundae', 'topping', 'analogies', 'but', 'not', 'leftovers!']
# [':', 'uhhh,', 'exams', 'start', 'tuesday.', ',', 'this', 'year', 'went', 'by', 'FASSSST!']
# ['@Blueash22', 'that', 'case,', 'we', 'may', 'well', 'get', '...', 'case.', 'would', 'non-wheaty', 'beer;', 'otherwise,', 'I', 'would', 'doubly', 'punished.']
# ['@BobMabena', 'no', 'beers', 'too', 'lazy', 'go', 'bottle', 'store']
# ['@BeckyBuckwild', 'That', 'good', 'one', 'though']
# ['@ChristineGrimm', 'Im', 'struggling', 'listening', 'very', 'smart', 'presenter', 'wearing', 'dress', 'tennis', 'shoes--CREDIBILITY', 'SHOT!!']
# ['<3', 'God', 'on', 'MY', 'Side.']
# ['@codecutr', 'know', '!', 'i', 'think', "'s", 'first', 'time', "we've", 'gone', 'this', 'year', 'that', "hasn't", 'been', 'either', 'cold', 'or', 'raining', 'or', 'both.']
# ['@AnthonyShelton', 'THANK', '!!', '#FF']
# ['@AlexanderRybak', 'AMAZING', 'musician.', 'Fairytale', 'performance', 'on', 'Eurovision', 'blew', 'me', '.', 'Keep', 'up!', "Can't", 'wait', 'hear', 'more!']
# ['@1SHAWNL', 'luv', 'ya', 'still', 'girlie.', 'I', 'mean', 'u', 'iz', '30', 'years', 'old', '&', 'shit.', 'I', 'expect', 'u', 'too', 'cook', 'breakfast.', 'smile', 'Hun.']
# ['@Adrianblee', 'so..', 'can', 'u', 'help', 'me..?']
# ['@candicotton', 'That', 'sucks!', "I've", 'done', 'that', 'b4', 'but', 'remember', "'s", 'plently', 'of', 'fish', 'sea!']
# ['@All_aboutariel', 'uhh', 'yeahhh,,,', 'i', 'ready', 'LN,', 'i', 'FUN!!', 'Thanks', 'FIX!!!!']
# ['@_JzL_', 'happy', 'echelon', 'day', 'gnight!', 'Sleep', 'well']
# ['@angelaiblackmer', 'relaying', 'stuff', 'by', 'email,', 'that', 'color', 'thing', 'earlier--', 'bit', 'too', 'much', 'at', 'once']
# ['@BadBoyOfEditing', 'True', 'Blood', '-', 'nice!', 'No', 'season', '2', 'spoilers', 'please!']
# ['@ashley_sunshine', 'yeah', 'if', 'i', "wasn't", 'typical', 'college', 'student', 'poor', 'i', 'totally', 'would', 'miss', 'too!']
# ['@bbb10tamosai', 'Get', '100', 'followers', 'day', 'using', 'www.tweeterfollow.com', 'Once', 'add', 'everyone', 'on', 'train', 'or', 'pay', 'vip']
# ['@0summerbreeze0', 'omg', 'crazy!', 'if', 'ur', 'blowing', ',', 'id', 'def', 'blow', 'second', 'i', 'stepped', 'outside!', 'i', 'remember', 'last', 'summer', 'scorching', 'hottt']
# ['@aerobic247', "I'm", 'on', 'ulimited', 'texts,', "I'm", 'serial', 'texter!']
# ['@britaiin', 'iknowrite']
# ['@aalaap', '@9_6', 'every', 'new', 'app', 'now', 'hav', 'b', 'compatible', 'iPhone', '3.0', 'software']
# ['@bunnyteeth', 'ps!', 'would', 'like', 'make', 'me', 'banner,', 'love?', "i'm", 'still', 'working', 'on', ',', 'so', "'d", 'ton', 'of', 'time!!']
# ['@Athirn', 'Ð¥Ð¾Ñ\x80Ð¾Ñ\x88Ð¸Ð¹', 'Ð¿Ñ\x80ÐµÐ·ÐµÐ½Ñ\x82Ð°Ñ\x82Ð¾Ñ\x80?', 'Ð\x98Ð»Ð¸', 'Ñ\x87ÐµÐ¼', '?', 'Ð\x92Ñ\x80Ð¾Ð´Ðµ', 'Ð½Ðµ', 'Ð¿Ð¾Ñ', 'Ð¾Ð¶)']
# ['@amoir', 'look', 'wonderful', 'not', 'matter', 'what', 'attire', '!']
# ['@aditya', 'awesome', 'idea']
# ['@canuck1975', 'look', 'like', 'really', 'great', 'time!', 'Congratulations,', 'dude']
# ['@antwerpenr', 'interesting', 'shot', '-', 'my', 'first', 'thought:', "'who", 'drilled', 'hole', 'North', "Pole?'"]
# ['@Ajaylongkaka', 'but', 'what', 'if', 'we', "don't", 'class', 'together.', 'will', 'like', 'sad.', 'Ha']
# ['@changibedsheets', "Basti's", 'thing', 'loading', 'but', 'slowly', 'so', 'I', 'hope', 'I', 'can', 'combine', 'both', 'end']
# ['@BambiFiasco', 'whoa', 'yeah', 'i', 'def', 'feel', 'youu.', 'i', "don't", 'even', 'need', 'that', 'unnecessary', 'ass', 'class', 'lls', '.', 'Spring', 'Commencement', '2010', 'i', 'think', 'i', 'might', 'cry']
# ['@Applecored', '@thisstarchild', 'lawks!', 'think', 'I', 'will', 'need', 'up', 'my', 'vitamin', 'intake']
# ['.what', 'first', 'day', 'of', 'sc0oL.', 'im', 'exhausted', 'reaLLy.', '-_-']
# ['@cheezo', 'wud', 'wise', 'call', 'u', 'twitterbaaz', 'now']
# ['@bpaciorka', 'but', 'looks', 'so', 'cool!', 'Hey!', "'re", 'by', 'my', 'house!', '...', 'Only,', "I'm", 'Louisiana...']
# ['@chas_in_aus', 'Thanks', 'so', 'much', '#followfriday', 'love.', 'Really', 'appreciate', '!']
# ['@aussiemcflyfan', 'hehe', 'cool']
# ['@amara_m', "'s", 'best', 'find', 'out', 'now', 'whether', 'can', 'hang', 'or', 'not', 'I', "don't", 'get', 'offended', 'when', 'people', 'unfollow', 'me,', 'all.']
# ['@Anime81', 'lunch', 'first,', 'then', 'Disney', 'store,', 'Borders,', 'then', 'home', 'manicures.']
# ['@charlestrippy', 'meannnssss...', 'visit', 'naughty', 'websitesss..', 'Ooo', 'Shame', 'shame']
# ['@amypalko', 'Mom', 'doing', 'good,', 'but', 'baby', 'cries', 'lot', '(', 'lot!)', "we're", 'already', 'investigating', 'possible', 'food', 'allergies']
# ['@B_smak', 'but', 'who', 'relation', '?', 'just', 'randomly', 'said', '.', 'so', "i'm", 'pretty', 'sure..', 'nob']
# ['@', '#Tesco,', 'like', 'my', 'fish', 'display?', 'Lemme', 'know', 'what', 'think!', 'http://twitpic.com/4h4ga']
# ['@Anthony_y_Tony', 'yesssssssssssssssssssss']
# ['@AviMarfia', 'hehe', 'iya', "'re", 'welcomee']
# ['@CalebMasland', 'exciting', 'times', '.', 'definitely', 'priorities', 'right', 'places!', 'good', 'luck', 'with', 'baby', 'training']
# ['@csi_ceri', 'Knocking', 'on', 'wood', '.', 'Or', 'erm,', 'whatever', 'weird', 'board', 'on', 'my', 'computer', 'desk', 'masking', 'itself', 'wood.']
# ['@caitlindsmith', 'hehe', 'x', 'me', 'too', 'x']
# ['@aileen2u2', 'awww,', "don't", 'embarrassed', 'more', 'than', 'correct,', 'sweets!']
# ['@amybeth23', 'me', 'too,', 'but', 'would', 'waste', 'of', 'money', 'none', 'of', 'computers', 'my', 'house', 'powerful', 'enough', 'run']
# ['@87sal87', "I'm", 'getting', 'launch', 'show', 'right', 'now,', "I'll", 'catch', 'up', 'on', 'all', 'today', 'Give', 'me', 'something', 'look', 'forward', 'lol', '*random', 'hugs*']
# ['@', 'work', 'cnt', 'wait', 'till', 'friday', 'going', 'GA', 'suprising', 'pops', "Daddy's", 'Day']
# ['#squarespace', 'needs', 'Larry', 'get', 'back', 'w/', 'my', 'car']
# ['@ashleyrhea', 'heyyy,', 'i', "couldn't", 'call', 'tonight', 'go', 'out', 'my', 'phone', 'still', "isn't", 'turned', 'on.', 'did', 'fun?', 'what', 'doing', 'tuesday?']
# ['@cnganesh', 'I', 'seen', '..', 'esp', 'alba']
# ['@CMTwitterhouse', 'Johnny', 'Depp', 'certain', 'roles', "I've", 'fallen', 'love', 'with', 'several', 'times', ';-)']
# ['@BEETLEbum_', 'meh', 'that', 'sucks,', 'soz!']
# ['@Admance', 'still', 'raining', 'down', '?']
# ['@bearded_stu', 'ooo', 'hobbit', 'follows']
# ['@aimeeeex:', 'Its', 'kinda', 'sad', 'because', 'i', 'dont', 'know', 'how', 'cookk..', 'thank']
# ['@art_pollution', 'OH', 'MY', 'gosh!', 'Wow', 'I', 'so', 'sorry!']
# ['@Anyelday', 'I', 'would', 'sad', 'too!', 'What', 'does', 'hubby', 'do', 'that', "haven't", 'seen', '?']
# ['@Britt7094', 'Oh,', "that's", 'sad', 'Bad', 'dog']
# ['@BerlyAnne', 'part', 'of', 'great', 'conspiracy', 'I', 'sure']
# ['nuffin', 'more', 'eckkky', 'that', 'i', 'cant', 'take', 'beside', 'being', 'disrespect', ':O', 'being', 'ignore...blahhhhhhh']
# ['::', 'Just', 'finished', 'watching', 'my', 'daily', 'dose', 'of', 'Philippine', 'soap', 'opera.', 'Mas', 'updated', 'yata', 'ako', 'ngayon', 'kaysa', 'dati', 'na', 'nasa', 'Pinas', 'ako.']
# ['@CHIOMA_', 'im', 'glad', 'ur', 'back', 'babezzz', 'so', 'much', 'BS', 'around', 'here', 'i', 'missed', 'ya']
# ['@CA_Young', 'semi-tempted', 'see', 'if', 'this', 'will', 'set', 'off', 'web', 'filter', 'at', 'work,', 'but', 'probably', 'not', 'best', 'idea', 'given', 'latest', 'unemployment', 'stats']
# ['@Alexnesia', 'haha', 'maybe', 'my', 'thumbs', 'paying', 'today', 'though']
# ['@ConciseKilgore', 'welcommmmmme!!', 'btw..i', 'heard', 'at', 'strip', 'bar', 'last', 'nite???', 'tavie...tavie...tavie........', 'tsk', 'tsk!!!']
# ['@AmyClipston', 'Go', 'with', 'muses', 'or', 'meat-free', 'Mondays???', 'Heck,', "I'll", 'do', 'both!', 'LOL!', 'Thx,', 'Amy!']
# ['@andopolis', 'thats', 'no', 'good...']
# ['*yawns*', 'going', 'bed', 'wrap', 'up', 'amazing', 'weekend!', 'Back', 'proverbial', 'grind', 'tomorrow']
# ['@aerynblack', 'Buying', 'iPhone!', 'Ahhh,', 'really', 'want', 'see', 'those', '@dramamagazine', 'pictures', 'badly,', "don't", '?']
# ['@bearskunk', 'ooh', 'go', 'with', 'ibook!', 'welcome', 'apple', 'world']
# ['@_annie2', '@davidismyangel', 'Thanks,', "i'm", 'not', 'sneezing', 'much', 'but', 'my', 'head', 'hurts.']
# ['@avb252', 'i', 'think', "i'm", 'not', 'going', 'any', 'where', 'boringggg']
# ['@compsolutions', 'That', 'one', '?B', 'tweet.']
# ['@absolutions', 'i', 'do!', 'i', 'internet', 'so', 'long...*hugs', 'internet*...but', 'at', 'least', "i'm", 'back', 'time', 'porn', 'battle.']
# ['@CManzzzz', 'Yup....', 'little', 'sad', 'but', 'at', 'least', 'i', '3', 'peeps', 'i', 'know', 'who', 'reading', 'reply']
# ['@azrillunatic:', '@xmellyssax', 'ooo', 'tu', 'bkn', 'problem', 'tweetdeck,', 'tu', 'sbb', 'internet', 'connection', 'u', 'slow,', 'i', 'dok', 'kerap', 'jadik..', ':', 'ye', 'ke?', 'ok.', 'now', 'i', 'know']
# ['@bareftbeachbaby', 'sounds', 'like', 'good', 'problem...', 'herdsires,', 'not', 'weeds.']
# ['@ambermaishment', 'yes', 'obsessed', 'but', 'its', 'good', 'thing', 'baby', 'becuase', 'now', 'im', 'not', 'on', 'my', 'own', 'land', 'of', 'twitter', 'rml', ';)']
# ['@1root', 'oh', 'yeees!', 'I', 'like', 'Terminator', 'too!']
# ['@ChayaChilde', '-', 'I', 'wish']
# ['@Cindralove', 'wow...', "that's", 'pretty', 'good.', 'oh', 'geeksquad', 'sucks', 'total', 'ass.', 'good', 'luck', 'with', 'whatever', 'that', '...']
# ['@BrandyandIce', 'not', 'playing', 'till', '5.15,', "can't", 'watch', 'tho', ',', "'s", 'on', 'setanta']
# ['@cArtPhotography', 'nope', 'still', 'all', 'messed', 'up', '@couldbestudios', 'going', 'try', 'fix', 'this', 'weekend,', 'thank', 'goodness...!']
# ['@ANGIEB222', 'oh', 'wow!', 'So', 'now', 'I', 'gotta', 'make', 'sure', 'I', 'come', '@', 'correct']
# ['#dontyouhate', 'when', 'ppl', 'update', 'too', 'fast', 'cant', 'keep', 'up']
# ['@BNow', 'Thanks', '@BNow!']
# ['@amelliathebeast', 'nawwww', 'thankyouu']
# ['@', 'Midnight', 'I', 'will', 'soon', 'Dreamland', 'hopefully', 'dream', 'another', 'dream', 'inspiration', 'future!!!', 'Lets', 'think', 'good', 'thoughts', 'now']
# ['@abideedles', 'mm!', "'re", 'just', 'torturing', 'me', 'today', 'my', 'girls', 'out', 'playing', "josie's", 'little', 'pool.']
# ['@alitherunner', 'I', 'posted', 'pics', 'of', 'new', 'puppy', 'but', "can't", 'repost', 'my', 'cell.', 'could', 'scroll', 'down', 'or', "I'll", 'repost', 'when', 'home.']
# ['*Not*', 'upgrading', 'iPhone', 'OS', '3.0', '@iphonemms', "doesn't", 'work.', 'Apple', "won't", 'approve', 'latest', 'version']
# ['@amyshell', 'Hope', 'so!']
# ['@amybarton', 'Hope', 'son', 'okay!']
# ['@ciaobella6', 'i', 'found', 'yea']
# ['@bkkrakora', 'ew,', 'i', 'used', 'get', "'suicides'", 'high', 'school', 'mix', 'like', '5', 'sodas', 'together.', 'then', 'drink', '.', 'i', 'think', 'i', 'remember', 'enjoying', ',', 'too.']
# ['@Bwrenn', 'how', 'been?']
# ['@bfhguides', 'Thats', 'cool']
# ['#andyclemmensen', '#bradiewebb', '#shaundiviney', '#shortstack']
# ['@adammshankman', 'i', 'didnt', 'think', 'max', 'should', 'gone']
# ['@brainychick25', 'hahaha!', 'Who', 'eats', 'mOst?']
# ['@aah1981', 'thats', 'hot.']
# ['@avi_kaye', 'Well,', "'s", 'not', 'all', 'about', 'that', 'single', 'subject!', 'covers', 'whole', 'lot,', '4000', 'years', 'of', 'history']
# ['@', 'Iowafoodcoop.', 'Hearing', 'about', 'my', 'Leg', 'of', 'Lamb.', 'Sally', 'just', 'hung', 'up', 'on', 'me.']
# ['@basgr', 'If', 'need', 'help,', 'just', 'tell', 'me.', 'I', 'live', '15', 'minutes', 'airport']
# ['@Cookie_Day', 'ahw', 'username', 'cute', 'haha']
# ['@', 'mall,', 'with', 'char', 'ron.']
# ['@antipov', 'Thank', '.']
# ['@abster5', 'ummmmm', 'get', 'meet', 'my', "'boyyyyyfriendd.'"]
# ['@AaronMonheim', 'Thanks.', "I'll", 'bitch', 'at', 'later.', 'Glad', 'got', 'safe/Sorry', 'I', 'missed', 'yesterday/', 'good', 'summer', 'big', 'bro!']
# ['@artyjill', 'Yep,', 'lot', 'of', 'good', 'scenery', 'here', 'whereabouts', 'did', 'visit', 'when', 'here?']
# ['@annosuperstar', 'Need', 'Anno', 'time', 'too.']
# ['@cazm', "s'what", 'I', 'expected,', 'but', 'lose', 'nothing', 'by', 'asking']
# ['#spotify:', 'one', 'of', 'biggest', 'joys', 'of', 'being', 'european']
# ['#BGT', 'Dream', 'Bears', '-', 'Hahaha', 'I', 'love', 'guys...even', 'with', "'wardrobe", 'problem.', 'Lol']
# ['@creativetallis', 'mine', 'no', 'working', 'yet']
# ['@akomuzikera', 'HAHAHAHAHAH', 'I', 'thought', 'I', 'following', 'already..I', "don't", 'know', 'what', 'happened.', 'sorry', 'ha?']
# ['@aplusk', 'I', 'know', 'aye...', 'late', 'night!!', 'LOL~', 'XOXO']
# ['@101wrif', 'We', 'already', 'know', "what's", 'next', 'Wings-GOLF...', "'Still", 'Stung', "Detroit'."]
# ['#squarespace', 'I', 'think', 'everyone', 'winning', 'but', 'me']
# ['@3RDegree09', 'man', 'i', 'still', "haven't", 'seen', 'that', 'movie...too', 'bad', "i'm", 'at', 'work']
# ['@_ena_', 'call', 'that', 'crowd?']
# ["'Welcome", 'home', "asshole'", '$1,000,000', 'person', 'who', 'understands', 'that,', 'good', 'luck', 'yall']
# ["'I", "McLovin'", 'watching', 'superbad']
# ['@', 'Home', 'week', 'end', '(3', 'days)', ',', 'Sophia', 'Antipolis', 'French', 'Riviera,', 'unfortunatelly', 's', 'raining']
# ['@Bash', 'Oh,', 'I', 'envy', '!', 'sleep', 'saboteur', 'not', 'sleeping', 'much', 'these', 'days', 'bf', 'thinks', "'s", 'fine', 'go', 'bed', 'at', '2', 'get', 'up', 'at', '11']
# ['@CoachDeb', 'haha', 'no', 'not', 'yet...', 'but', 'i', 'will', 'soon', 'if', 'i', "don't", 'get', 'bed', 'now...', 'so', 'this', 'my', 'final', 'tweet................', 'now']
# ['@alexdechiel', 'I', 'hope', 'delicious!!!', 'I', '<3', 'ice', 'cream,', 'BUUUUUT', 'makes', 'my', 'tummy', 'too', 'rumbley']
# ['@a_simple_girl', 'Glad', 'someone', 'appreciates', 'my', 'humor.', '*hugs*', "I'm", 'pretty', 'sure', "I'm", 'gonna', 'limping', 'again', 'today.', 'Darn', 'foot!', 'Love', 'too!']
# ['@answertowhy', 'i', 'LOVE', 'that', 'show.', 'i', 'think', 'online', 'version', 'of', 'game!', 'http://www.fox.com/dontforget/features/']
# ['@brodyjenner', 'http://twitpic.com/6ryep', '-', 'Lmao!!!', 'Oh', "that's", 'horrible']
# ['@aubreyoday', 'http://twitpic.com/6blez', '-', 'Look', 'Nice', 'Aubrey!', 'Go', 'Girl']
# ['@Candypants2', 'I', 'just', "haven't", 'good', 'experience', 'with', 'phones,', 'but', 'coverage', 'fine', 'here']
# ['@CSI_PrintChick', 'Whaaa?', 'I', 'Love', 'songs.', 'Its', 'not', '!']
# ['@aeontheace', 'Get', '100', 'followers', 'day', 'using', 'www.tweeteradder.com', 'Once', 'add', 'everyone', 'on', 'train', 'or', 'pay', 'vip']
# ['@bizziefan', 'i', 'know..', 'that', 'so', 'stupid', 'bizz..', 'glad', 'twitter', 'working', 'again']
# ['@bondibeachgirl', 'i', 'suuure', 'did', 'hahh.', 'samples', 'of', 'my', 'album', 'everything', 'yayy']
# ['@Bookwhisperer37', 'i', "won't!"]
# ['@coliwilso', 'not', 'much', 'blipping', 'lately,', 'but', "i'll", 'get', 'onto', 'that', '.']
# ['@billyraycyrus', 'omgg', 'YAY!', 'coming', 'new', 'zealand', 'too?', 'please', 'say', '!', 'im', 'soo', 'excited', 'ill', 'front', 'row!']
# ['@amanda_loves_jb', 'may', 'up', 'bit', 'with', 'all', 'that', 'caffeine!']
# ['@1azylizzie', 'good', 'luck', 'on', 'move', 'once', 'again']
# ['@b4dilist', 'I', 'feel', 'same', 'way', 'about', 'Saturday!']
# ['@Boomaconda', "can't", 'leave', 'us,', 'Bruno!']
# ['@chewwbear', 'Oh', 'yeah...lobsters!', 'My', 'dad', 'asked', 'me', 'buy', 'fresh', 'one.', 'Yikes!', "Weather's", 'not', 'good.', 'going', 'back', 'June.', 'Yey!']
# ['@avaiIable', 'My', 'American', 'Flag', 'background', 'my', 'American', 'friends', 'i', 'got', 'loads...', 'no', 'its', 'cross', 'between', 'kiwi', 'scouse..']
# ['#mudeideassunto', 'I', 'miss', 'of', '@isjoin!!']
# ['@cardsforheroes', 'hey', 'cool,', 'would', 'hated', 'miss', 'sunshine']
# ['@Alli_Flowers', 'great', 'season', '!', 'So', 'who', 'exactlly', 'Jacob', '&', 'friend', 'loophole', 'finder', '?']
# ['@agerstein', 'update', 'probably', 'just', 'us,', "i'm", 'europe']
# ['@blind_baseball', 'Thanks', 'so', 'much', 'wonderful', 'message!']
# ['@carlitosmum', 'Ohh', 'lush.', 'My', 'Nan', 'lives', 'down', 'Devon,', 'East', 'Allington', '(', 'Totnes)']
# ['@Cath_Preston', 'message', 'Greenford', 'carnivorous', 'fauna,', 'actually', '-', 'but', 'knock', 'yourself', 'out']
# ['@', 'HaNnah0116', 'Its', 'little', 'too', 'late', 'now.', 'My', 'weekend', 'afternoons', 'evenings', 'too', 'busy.']
# ['@BrainTwitch', 'Boo,', 'I', 'project', 'due', 'meeting', 'at', '10:00', 'tomorow', 'that', "I've", 'been', 'working', 'on', 'all', 'night']
# ['@AmyyVee', 'byee', 'cya', 'tomoz!']
# ['@Aquabub', 'Not', 'telling!', 'When', 'I', 'go', "I'm", 'going', 'hibernate', 'deep', 'inside', 'secret,', 'warm', 'cave', 'sound', 'of', 'tweeting']
# ['@anitasetio', '@serenetan', '@maynaseric', 'maybe', 'i', 'record', 'some', 'singing', 'let', 'check', 'out']
# ['@Beeyezzy', 'i', 'will', 'best', 'ost.', 'u', 'can', 'ask', 'any', 'of', 'my', 'friends.', 'I', 'always', 'make', 'sure', 'my', 'friends', 'good', 'time.']
# ['@bonafide_hustla', 'Welll', 'I', 'no', 'but', 'its', 'hard', 'I', 'need', 'youu']
# ['@BritniSherlock', 'Too', 'bad', 'probably', "don't", 'any', 'books', 'about', 'pink', 'sink']
# ['@AussieCatDoll', 'http://twitpic.com/6q8x3', '-', 'Haha', 'then', 'so', 'lucky', ';D', 'Nah', 'me', 'not,', 'but', 'Im', 'sure', 'she', 'can', 'Btw', 'pic', 'rly', 'awesome']
# ['@afirmin', 'Please', 'meet', "'Poet", 'of', "Twitter'", 'xox', 'Lori']
# ['@BrentCsutoras', 'not', 'me..', '..', 'but', 'Mike', 'will']
# ['@anguyen33', 'wish', 'i', '!!!', 'hope', 'fun!!']
# ['i', 'dont', 'like', 'fact', 'my', 'gay', 'best', 'friend', 'tears...', 'â\x99¥']
# ['@CohenOZXDS', "I'm", 'afraid', 'my', 'theatre', 'exile', 'will', 'go', 'on', 'forever.']
# ['@1capplegate', 're', 'tweet...']
# ['@amari_mishca', 'Thanks!', 'I', 'hope', 'heat', "won't", 'get', 'me']
# ['@aaroncues', '-', 'omg!', 'what', 'did', 'we', 'just', 'get', 'ourselves', 'into?!', 'cant', 'wait', 'shed', 'lbs!!!']
# ['@AlexaRPD', 'scary', 'but', 'exciting']
# ["'through", 'storms', 'night,', 'baby', 'stood', 'by', 'my', "side'", 'http://twitpic.com/6g80m', "G'night", 'twitterverse!', 'Gym', 'final', 'morning']
# ['@ajamark', 'Awesome!', 'Travel', 'safe', 'guys', 'doing', 'live', 'shoot', 'with', 'KiPro', 'on', 'tour', 'dropping', 'clip', 'into', 'FCP?']
# ["'B.Y.O.B.", 'stands', "what?'", "'bring......own....bitch!'"]
# ["'severe", 'weather', 'outbreak', "midwest,'", 'says', 'weather', 'channel.']
# ['@bernadinee', 'Sims', '3', ',', '11', 'days', 'release', 'n', '15', 'days', 'me', 'touch', 'cd']
# ['@Akelaa', 'I', "don't", 'know,', "I'm", 'reading', 'book', 'Regulators,', 'Desperation.', 'Good', 'catch!']
# ['@AndrewDearling', 'its', 'true!', 'listening', '2', 'mp3', 'work', '&', 'flickin', 'thru', 'anything', 'not', '90s', 'lol...need', 'more', 'on', 'wish', 'spotify', 'did', 'that!']
# ['@alivicwil', 'Thanks.', 'Just', 'knowing', "'re", '&', 'thinking', 'of', 'us', 'enough', 'Oh,', 'unless', 'wanna', 'lend', 'me', '$5k', ';)', 'Just', 'kidding!']
# ['@AaronLHB', 'got', 'watch?', 'Thts', 'sooooo', 'sweet']
# [',,,checked', "del's", 'new', 'blogsite!!!', 'YAHOO!!!', 'im', 'just', 'excited', 'what', 'will', 'bring', 'go', 'del!']
# ['@BlokesLib', 'that', 'made', 'me', 'cry']
# ['@_Flik_', "'ll", 'sweet', 'talk', 'make', 'sure', 'she', 'knows', 'hard', 'worker.']
# ['@AnnCurry', 'Morning']
# ['@adriane_says', 'definitely', 'bout', 'glowsticks', 'n', 'trance', 'music,', 'lmao', 'at', 'weed', 'smokin', 'cant', 'roll,', 'sht', 'thats', 'me']
# ["'we're", 'misting', 'each', "other!'", "I'm", 'bored', 'already', 'but', 'jose', 'looks', 'good', 'that', 'pic.']
# ['@biancaawesome', 'we', "haven't", 'talked', 'while']
# ['@Chick76', 'oh', 'no']
# ['@amandaperson:', 'niiiight', 'dream', 'sweetly.']
# ['@carece', 'Hope', 'week', 'been', 'wonderful.', 'Thank', '#FF', 'recommendation.', 'Looking', 'forward', 'catching', 'up', 'soon.']
# ['@AnnieDAFG', 'awwww', 'that', 'sucks', '((', 'RIP', 'Annies', 'dog']
# ["'house'", 'holy', 'moly,', 'not', 'moment', '2', 'soon!']
# ['@AiyerChitra', 'Big', 'time', 'into', 'strobing,', 'eh?', 'Nice', 'link', '-', 'Missed', 'earlier!']
# ['@christophermc', "Kooks'", 'cover', 'also', 'really', 'awesome.']
# ['@camilleTheJonas', 'hey', 'i', 'want', 'also', 'hey', 'when', 'at', 'home', 'so', 'I', 'send', 'profile', 'girl', 'I', 'sit', 'with', 'she', 'Bus', 'I', 'dont', 'sit', 'with', 'she']
# ['@askaaronlee', 'I', "won't", 'recommend', 'this', 'comp', 'until', 'I', 'put', 'on', 'my', 'countries', 'wall', '!!', "won't", 'vote', 'either', '!', 'very', 'disappointed', 'my', 'friend', '!', 'very', '!!']
# ["I've", 'always', 'seen', 'bits', '&', 'pieces', 'of', 'Shottas.', 'now', "I've", 'seen', 'whole', 'movie...', 'ends', 'sooooo', 'sad', "I'm", 'gonna', 'cry.']
# ['@Annatr0n', 'this', 'my', 'old', 'one,', "wasn't", 'fully', 'deleted', 'apparently,', 'so', 'I', 'reopened!']
# ['@aboutlore', 'yeh...', 'sucks']
# ['@annielovee', 'texty', 'text.', 'Haha']
# ['@AirJeffreys', 'aeriel', 'only', 'off', 'thursday&fridaay', 'babe.']
# ['@ChilitoTwitts', 'PLEASE', 'CHECK', 'THIS', 'PIC', 'COMMENT', 'http://twitpic.com/6fl6k', 'ME', 'MAGAZINE', 'OF', 'MY', 'CITY']
# [':', 'I', 'saw', 'US', 'Postal', 'hiring,', 'but', 'once', 'I', 'done', 'filling', 'out', 'pre-application', 'thingy', "didn't", 'show', 'me', 'jobs', 'open', 'area.']
# ['@BlogKelly', 'i', 'bet', "'re", 'someone', 'who', "'loves'", 'kids', 'rather', 'than', "'lover'", 'kids']
# ['@coreydance', 'I', 'love', 'babe.', 'Thanks', 'putting', 'up', 'with', 'my', 'bullshit', 'past', 'year', "'re", 'my', 'everything.']
# ['@Carly6vmz', 'Thanks', 'follow,', 'I', 'like', 'where', 'coming']
# ['*warning*everythang', 'super', 'funny,', 'delayed', 'responses,', 'randomness,', 'i', 'need', 'sleep', 'but', 'i', 'refuse!', 'so', 'dnt', 'mind', 'me', 'less', 'u', 'wanna', 'mind', 'me']
# ['....my', 'heart', 'hurts', 'i', 'dont', 'know', 'why...i', 'hope', 'no', 'one', 'i', 'know', 'dying']
# ['@chrispalko', 'that', "'bad'", '6.5', 'out', 'of', '10', 'then?', 'because', 'I', 'consider', '6.5', 'out', 'of', '10', 'fairly', 'good', 'man.', "I'm", 'big', 'Termnator', 'fan']
# ['@bloodyironist', 'Oh', 'no,', 'poor', 'bb.', 'I', 'hope', "he's", 'okay...']
# ['@Arrens', 'hehe.', 'pretentious', 'pricks', 'need', 'taught', 'lesson.', 'hurt', 'my', 'little', "priest's", 'feelings']
# ['@astradaemon', 'try', 'typing', 'Millionaire', 'Wanted....I', 'wanna', 'see', 'what', 'happens']
# ['I', 'spent', 'my', 'sunday', 'arvo,', 'with', 'bottom', 'feeding', 'vulture,', 'stuck', 'up', 'lawyer', 'chick,', 'gawd', 'lowest', 'of', 'scum']
# ['@catmatson', 'thought', 'so', 'thnx', 'confirming..']
# ['@Adrojake', 'one', 'tv', 'parentals', 'overruled', 'with', 'ncis.', 'i', 'hate', 'my', 'family', 'sometimes', 'hahahah']
# ['@6morningnews', 'Got', 'up', 'this', 'morning', 'specifically', 'see', 'shuttle', '(', 'front', 'yard)', 'Morning', 'not', 'total', 'loss', 'thanks', 'guys.']
# ['@BellaBKNY', 'took', 'long', 'nap', 'earlier,', 'now', "I'm", 'wide', 'awake', 'so', "'s", 'movie', 'time.']
# ['Body', 'Of', 'Missing', 'Northern', 'Calif.', 'Girl', 'Found:', 'Police', 'found', 'remains', 'of', 'missing', 'Northern', 'California', 'girl', '..', 'http://tr.im/imji']
# ['@bummerbash', 'i', 'honestly', 'just', 'left', 'my', 'cabinet', 'next', 'thing', 'i', 'knew,', 'gone!', '(', 'i', 'think', 'someone', 'stole', '...']
# ['@#odna', 'I', 'think', "I'm", 'out', 'night']
# ['@ColtonTran', 'Rochelle', 'taking', 'pics?', 'YAY!', 'Haha.', "She's", 'awesome,', 'gotta', 'love', '.', 'fun!', 'Hopefully', 'I', 'get', 'see', 'these', 'shots,', 'yeah?']
# ['@aplusk', 'Scariest', 'of', 'all', "tho'", 'ventriloquist', 'dummies', '*shudders*', 'I', 'would', 'nervous', 'breakdown', 'if', 'I', 'sleep', 'with', 'one', 'my', 'room']
# ['@beforeyoufallx', '*sigh*', 'seems', 'got', 'bed', "we've", 'been', 'playing', 'phone', 'ping', 'pong', 'all', 'day']
# ['good', 'dance...', 'make', 'little', 'love...', 'get', 'down', 'tonight...!!!!', '<3']
# ['@23graeme23', 'Aw', 'thx,', 'Well', 'I', 'think', 'u', 'will', 'my', 'only', 'followfri', 'this', 'week', "I'm", 'tryin', 'catch', 'up', 'on', 'e-mail', '&', 'new', 'tracks..', 'Talk', 'soon', 'tho!']
# ['@Chalmes', 'another', 'its', 'taking', 'ages', 'anaw', 'Av', 'no', 'nuhin', 'eat', 'all', 'day']
# ['@1stladyRetroKid', 'sounds', 'dope.', 'whats', 'dress', '4?', 'ur', 'party', '2morrow?', 'cant', 'wait', '2', 'c', 'pics!', 'wish', 'we', 'could', 'make', 'eachothas', 'events!']
# ['@corduroy', 'Ahhh..', 'thanks']
# ["''s", 'my', 'birthday', "I'll", 'cry', 'if', 'I', 'want', "'", 'because', 'now', "I'm", '30']
# ['@BrittdixonPINK', 'fa', 'real.', 'That', 'makes', 'me', 'so', 'mad.', 'Imma', 'change', 'that', 'when', 'i', 'make', '.']
# ['@abrowngirl', 'man', 'what?!', 'See', 'I', 'this', 'issue', 'with', 'chuckling', 'at', 'others', 'misfortune...', 'I.e.', 'People', 'running', 'fullspeed', 'into', 'objects,', 'etc']
# ['@amalucky', 'work', 'that', 'tan']
# ['@ashley_is_here', 'but', 'I', 'wanna', 'know']
# ['@bivester', 'we', 'madison,', 'indiana', 'folk', 'festival.', 'i', 'should', 'just', 'called', 'anyway!']
# ['...working', 'until', '6']
# ['@Chocolatedonout', 'good', 'luck', 'Line,', 'no', 'reason', 'nervous', 'i', 'guess.', 'that', 'oral', 'english', 'exam?', 'if', ',', "'ll", 'do', 'great']
# ['@CindyLoves', 'I', 'love', 'those', 'listings']
# ['@AntonioCapo', 'embarassing', '-', 'most', 'peeps', 'delighted', 'recognized!']
# ['@chicagomichael', "'s", 'not', 'middle', 'of', 'night', 'everywhere']
# ['@19fischi75', 'holy', 'cow!', 'then', 'pls', 'careful', 'hun!', 'take', 'no', 'risks!']
# ['@aulku', 'i', 'know,', 'i', '-', 'ahaha', 'oh', 'noooo!', 'she', 'loved', 'outfit', 'almost', 'much', 'we', 'did']
# ['!@jenscloset', "didn't", 'invite', 'me?']
# ['@aaroncarter7', 'why', 'dont', 'i', 'ever', 'get', 'reply', '?']
# ["'Some", 'rise', 'by', 'sin,', 'some', 'by', 'virtue', "fall'", '-', 'irony', 'of', 'life!', 'Good', 'Morning', 'again!']
# ['@AnaiNumba1', 'luv', 'that!!!']
# ['@anthonyblando', 'Ah', 'no,', "wasn't", 'me.']
# ['..Collecting', 'sun', 'vectors..']
# ['@amirsulaiman', 'LOL', "I'm", 'up', 'ready', 'record', 'but', 'I', 'need', 'start', 'my', 'ritual', 'I', 'do.', 'Some', 'ginseng', 'tea']
# ['@badassyella', 'if', 'makes', 'u', 'feel', 'better', 'I', 'stunned', 'my', 'small', 'toe', 'on', 'night', 'stand', 'thinking', 'I', 'late', '4', 'work...', 'my', 'day', 'off']
# ['@_tr', "didn't", 'get', 'ticket,', 'or', 'just', "can't", 'go?']
# ['@Bensue', 'ur', 'not', 'on', 'msn']
# ['@AlexAnansi', 'oooh', '-', 'interesting!', 'little', 'indie', 'me', 'perhaps', 'but', 'concept', 'indeed', 'looks', 'awesome']
# ['@30secondstomars', 'http://twitpic.com/6dd5l', '-', 'we', 'say', 'french:', 'le', 'travail', 'porte', 'ses', 'fruits']
# ['@boysandclothes', 'Thanks', 'greetings.', 'Right', 'back', 'at', 'yah', 'Lovely', 'site', 'got', '...']
# ['@adamnyholt', 'Oh,', 'good', 'God!', 'I', 'will', 'certainly', 'say', 'prayer', '.']
# ['/', 'goodnight', 'bitches']
# ['-', 'HEY', 'YA', 'ALL!', '8)', 'Peace', 'Out!', '#Followfriday!', 'Please', 'i', 'want', 'followers!!!!', 'So', 'give', 'out', 'this', 'message:', 'Follow', '@Crizzyx3', 'THANKS!']
# ['@ChazHam', 'jolly', 'good', 'so', 'basically', 'redy', 'sum', 'bantz', 'did', 'u', 'see', 'wat', 'i', 'sed', '@fakerpattz', 'about', 'how', 'hurts', 'called', 'wanker?!x']
# ['@3os_knight', 'Yes', 'I', ',', 'ta']
# ['@allexsa', 'i', 'missed', ',', 'cus', 'we', 'went', 'Paris,', 'thinking', 'that', 'party', 'next', 'weekend', '...', 'still', 'gotta', 'do', 'something', 'this', 'week', 'u', 'leave!!']
# ['@arifgumussu', 'die', 'fake', 'btw']
# ['@BamaRandyGirl', 'aww!', 'Love', '!', 'Wish', 'I', 'came', 'earlier', 'so', 'I', 'couldve', 'been', 'with', 'u', 'guys!', 'hopefully', 'one', 'of', 'these', 'days..']
# ['@advanmatthew', 'esmosiii', 'vaaaan', 'abis', 'ngenyek', 'capres', 'yang', 'lain', '.', '.']
# ['My', 'MP', 'wanna', 'leave', 'at', '8', 'd', 'morning', '(Sh*t)']
# ['@aspo1', 'wotcha', 'mate,', 'hope', 'well?', 'nice', 'breeze', 'here', 'not', 'too', 'humid', 'yet', 'so', 'hopefully', 'no', 'storm', 'today']
# ['@bronte_saurus', 'Oh,', 'sweetheart!', "I'm", 'sorry!', 'tried', 'soup?']
# ['@christpherr', 'I', 'wondering', 'where', ',', 'haha.']
# ['@CherishmySTYLE', "I'm", 'trying', '.', "'s", 'not', 'easy']
# ['@corecast', 'HAHA', 'actually', 'no.', 'i', 'talking', 'about', 'how', 'many', 'drawers', 'left', 'out.', 'get', 'yo', 'mind', 'outta', 'gutter']
# ['@ashboob', 'u', 'need', 'go', 'sit', 'down.', 'Now.', "I'm", 'not', 'playn', '.']
# ['@annielftw', 'hi', 'twitterwhore', 'annie', 'i', 'nothing', 'tweet', 'about!!!!!', 'hahahaha.', 'how', 'do', 'twitter', 'text?!', ':O', 'crazayy']
# ['.@HempNews', 'I', 'know;', 'I', 'just', 'playing.']
# ['@_katpie', 'how?', 'ps', 'call', 'me!']
# ['@3CB', 'Slept', 'excellent', 'akshually,', '?', 'Even', 'me', 'I', 'want', 'read', "'Really", 'very', 'silly', 'poems)', 'like', '@Milonare', 'May', 'I??!']
# ['@BluntNate', 'LOL.', 'I', 'get', 'paid', 'day', 'off']
# ['@bradpuet', 'thanks', 'bro.', 'even', 'farts', 'cute...', 'when', "'re", 'not', 'messy.']
# ['-', 'Missing', 'my', 'girls', 'Northern', 'Cal,', 'but', 'enjoying', 'being', 'with', 'my', 'sons', 'Southern', 'Cal.', 'Magic', 'Mountain', 'here', 'we', 'come!!!', 'http://bit.ly/giN8R']
# ['@birbrilo', 'poet', 'being', 'born', 'today', 'on', 'Twitter']
# ['@_neon_blonde_', 'ha,', "that's", 'so', 'true']
# ['...need', 'learn', 'how', 'do', 'my', 'work']
# ['@Azodrac4J', 'I', 'Marine', 'brother....', "let's", 'just', 'say,', 'he', 'tried', 'that', 'already,', 'lol.']
# ['@a_rybak', 'Welcome', 'Munich.']
# ['...goddamn', 'ironing.', "'s", 'time', 'someone', 'invented', 'disposable', 'clothes', 'so', 'I', "don't", 'iron', 'same', 'thing', 'over', 'over!', '#fb']
# ['@buffalopine', 'Thanks', 'so', 'much,', 'I', 'appreciate', "'s", 'been', 'strange', 'day', 'lol...Peace...']
# ['@cebaugh', 'me', 'too,', 'time', 'bed..been', 'great', 'day...night', 'friends']
# ['@Chaoticshimmer', 'if', 'that', 'Paul', 'I', 'would', 'my', 'ass', 'already', 'line', 'see', 'sick', 'or', 'not.', 'I', 'will', 'grandkids', 'b4', 'I', 'see', 'again.']
# ['@bill_starr', 'Yep,', 'Hawkesbury', 'Classic', 'starts', 'at', 'Windsor,', 'home', 'of', 'said', 'DJ']
# ['@brandyecupcakes', 'me', 'too']
# ["'Designing", "Web':", 'Unboxing', 'http://bit.ly/8wHds', 'Thanks', '@markboulton!', 'Beautiful', 'book,', 'awesome', 'content!', '#fivesimplesteps']
# ['@_strokemyEGO', 'soooo', "...'s", 'just', 'one', 'story!?', 'lol']
# ['(@meesh31)', 'Frustrating', 'day', '#1', 'of', '4', 'potentials.', 'I', 'need', 'hug.', 'This', 'sad.']
# ['@chockenberry', 'cool', 'man.', 'sounds', 'like', 'case', 'closed', 'on', 'this', 'one,', '/me', 'opens', 'beer.']
# ['@ALOliver', 'Thanks', 'Alice,', 'really', 'glad', 'enjoyed', '-', 'told', ',', 'Curious', "don't", 'do', 'snobby,', 'down', 'with', 'that', 'sort', 'of', 'thing!']
# ['@childcraft', 'haha', 'well', "I'm", 'following', 'now']
# ['@CMyste', 'Very,', 'very', 'sweet', 'of', 'say!', 'I', 'just', 'get', 'percentages', 'right', 'now!', 'Posted', 'details', 'on', 'secret', 'blog.']
# ['@ChuckHall', 'dont', 'generally', 'hear', 'about', 'good', 'customer', 'service,', 'sadly.', 'only', 'when', 'something', 'goes', 'bad']
# ['no', 'mel', 'religion,', 'i', 'guess', 'im', 'spilling', 'all', 'my', 'boy', 'stories', 'jackie', 'tomorrow.']
# ['@CoilyMadness', 'my', 'baby', 'named', 'Brooklyn']
# ['@annaw1272', 'thats', 'deffo', 'real', 'miley', 'shes', 'even', 'said', 'on', 'interviews', 'tht', 'its']
# ['@alexalltimelow', "'ll", 'hang', 'out', 'show', 'on', 'friday', 'right?', 'I', 'forgot', 'ask.']
# ['Travel', 'sorted!', 'Went', 'into', 'town', '-', 'found', 'National', 'Express', 'disappeared', ':S', 'Thankyou', 'porn', 'internet!', 'I', 'now', 'e-ticket!']
# ['@aplusk', 'my', 'daughter', 'at', 'set', 'right', 'now', 'driveway.....wave', "(Tory)..'ve", 'been', 'nice', 'ppl', 'of', 'Woodstock..thx']
# ["i'm", 'just', 'lost']
# ['@awesomeful', 'Xanax', 'my', 'lifesaver,', 'tbh.', 'But', "don't", 'abuse', '.']
# ['@andij', 'yah,', 'but', 'PITA', 'soft', 'unlock', 'only', 'good', 'SD.', 'Not', 'sure', "'s", 'worth']
# ['@Brii_is_me', 'NO', 'my', 'mom', 'supposed', 'watch', 'Jacob', 'tonight', 'but', 'she', 'went', 'get', 'my', 'niece', 'forgot...']
# ['@90_angel', 'no', 'sun', 'here,', 'cloudy', 'this', 'morning']
# ['@CorkyIsCrazy', 'Haha', 'thank', '<3']
# ['@bangmeboy', 'Thanks.', 'I', 'worked', 'really', 'hard', 'on', ',', 'too.', '/stifles', 'sniffle.']
# ['@asot400', 'im', 'heaven']
# ['@annschilling', 'Get', '100', 'followers', 'day', 'using', 'www.tweeteradder.com', 'Once', 'add', 'everyone', 'on', 'train', 'or', 'pay', 'vip']
# ['@Bathbad', "I'd", 'like', 'think', 'so', 'we', "haven't", 'forgotten', 'really']
# ['@Bree253', 'haha', 'gotta', 'love', 'waiters', 'who', "don't", 'care', 'if', 'drink', 'all', 'of', 'moms', 'ginormous', 'margerita']
# ['@Bobbyedner', 'i', 'love', 'ya', 'bobby!', 'I', 'hope', 'good', 'day']
# ['@cArtPhotography', 'now', 'yes,', 'Jack', 'Johnson', 'not', 'loading', 'up']
# ['#followfriday', '@the_c_word', '@ipooped', 'going', 'nasty', 'this', 'week']
# ['#f1', '-', 'renault', 'spun', 'off', 'but', 'this', 'time', 'not', 'Piquet']
# ['@AudreyLizeth', 'Ahhh', 'why?']
# ['@ahlexas', 'awwwwwwwww', 'i', 'love', ',', 'thanks', 'so', 'much', '<3', 'i', 'love', 'youuuu', '!']
# ['@bbunderground', 'Good', 'morning']
# ['@CrackerCrumbie', 'No', 'one', 'said', 'better.', 'I', 'meant', 'add', 'comment', 'that', 'effect', 'well', 'but', 'twitterfailed.']
# ['@AwakenJournal', 'oh', 'I', 'notice', "don't", 'link', 'bio?!', 'that', 'could', 'also', 'why', ';)', 'go', 'up', 'settings', 'add', '!']
# ['Happy', 'Fathers', 'day.', 'ILUDaddy.', 'First', "father's", 'day', 'sans', 'father.']
# ['@alandavies1', 'links', 'announcer', 'guy', 'announced', 'result', 'show', 'started']
# ['@chxnguye', 'haha', 'yeah', '!', 'of', 'course', 'I', 'watch', 'Twilight', '!', 'haha.', 'I', 'love', 'ALL', 'books', 'haha.', '!']
# ['@ArsenalSarah', 'Oh', 'i', 'wish', 'i', 'going', 'Newquay', 'http://tinyurl.com/cog8yg']
# ['@_beckyboop', 'BECKY!', 'My', 'i', 'THINK', 'we', 'actually', 'going!', 'my', 'mum', 'like...', "'I'm", 'going', 'go', 'dream', 'about', "!'", "'s", 'also', "'cause", 'of', 'our']
# ['@CaptainRedmuff', 'WWDC', 'Developer', 'RC', 'builds', 'all?']
# ['@AdamNicholasB', 'My', 'sun', 'sign', 'Virgo;', 'hence,', 'my', 'relationship', 'with', 'Mercury/Hermes', 'rather', 'strong.']
# ['@Beth_Star85', 'haha', 'Hell!', "I'm", 'trying', 'hard', 'stay', 'awake', 'lucky', 'done', '!']
# ['@bephoebe', 'Can', 'we', 'replace', 'Gabriel', 'with', 'Don', 'Henley.', "I'm", 'recently', 'disturbed', 'that', 'my', 'iPod', 'no', 'Henley']
# ['@alkanphel', 'Good', 'point.', 'I', 'always', 'forget', 'vegetarian', 'sushi', 'options.', 'Haha,', 'might', 'well', 'eat', 'inari!']
# ['@BlokesLib', 'Someone', 'said', 'she', 'went', 'jail', 'yesterday', 'only', '13', 'tweets', 'hour..WTF????...', '3rd', 'incarceration', 'day', "tho'"]
# ['@Amy_Mayna', 'just', 'saw', 'vampire,', 'laughing', 'all', 'by', 'myself', 'haha', 'oh', 'Craig', 'LA', 'right', 'now!!']
# ['@ActionAmby', 'Night', 'at', 'Museum', 'on', 'FX.']
# ['@andrewkjs', 'sun', 'just', 'walked', 'with', 'tripple', 'stock', 'value']
# ['@CMRLee', 'because', 'when', 'tried', 'London', 'all', 'bikes', 'went', 'walkies']
# ['@Alex_Ball', 'What!!!!', 'free', 'biscuits?', '@jonoble', "'s", 'goodies', 'biscuit', 'free', 'zone', 'here!', "I'll", 'buy', 'my', 'own', 'bourbons', 'tomorrow']
# ['@_VNL', 'I', 'see', 'no', 'different', 'i', 'ipod', 'touch', 'I', 'pay']
# ['@_Enigma__', 'looking', 'forward', 'return...', 'take', 'care']
# ['@aliceakatea', 'relaxing', 'at', 'home', 'now', 'im', 'working', 'at', 'factory', 'where', 'manufactures', 'puzzles', 'like', 'pokemon', 'ones', 'other', 'stuff.', 'not', 'so', 'bad...lol']
# ['@blovitt', 'going', 'earlier', 'staying', 'night.']
# ["'Duet'", 'should', 'do', 'mix', 'tape']
# ['@bengillam', 'No', 'podcast,', 'we', 'technical', 'failure', "couldn't", 'save', 'recording']
# ['@ChrisCredendino', 'Rainy.', "I'm", 'trying', 'talk', 'everyone', 'into', 'hitting', 'up', 'mall', 'but', "we'll", 'see.', '<3']
# ['@cookiejac', 'Me', 'too', "'s", 'no', 'fun.', 'Plus,', 'we', 'need', 'more', 'money', 'future', 'tour.']
# ['@BiLLi0', 'Well', 'who', "wouldn't", 'So', 'first', 'minutes', 'of', 'episode', '12', '-', 'dream', 'sequence', '-', "wasn't", 'really', '3D...?']
# ['@childofdust', '*GIANTHUG*', "I'm", 'online', 'if', 'want', 'talk', '<33', '*CUDDLE*']
# ['@airrad', 'I', 'did', 'something', 'that', 'Basil', 'Fawlty', 'said', 'not', 'do.', 'That', 'may', 'bit', 'cryptic', ',', 'not', 'sure']
# ['#gogreensunday', '->', '@globalflashmob', '@Jayman888', '@papcelebrity', '@fatfat8ight', '@Greengamma', '@GoGreenClean', '@piece2dot0', '@EcoInteractive']
# ['@berkeleyan', 'i', 'totally', 'understand.', 'although', 'i', "don't", 'know', 'if', "'s", 'any', 'easier', 'focus', 'here...i', 'certainly', 'failing,', 'at', 'least!', ';)']
# ['@bananaexhibit', 'yeah', 'like', '15mins', 'lol.', 'gahhh', 'dreadin', 'this', 'exam']
# ['@aniskywalker', 'oh', 'that`s', 'nice,', 'well', 'done']
# ['@aplusk', 'lol,', 'Awesomely', 'sweet', 'dude!']
# ['@carlaaslan', ',', "I'd", 'l.o.v.e', 'hear', 'song', '.', 'Written', 'few', 'myself,', 'although', "'re", 'agess', 'ago', '.', 'lol']
# ['(@okimmydee)', '@ralphie_g', 'Oh,', 'my', 'heart', 'all', 'aflutter!', 'no', 'idea', 'coconut', 'cups', 'would', 'get', 'me', 'love.', 'Note', 'self...']
# ['..when', 'I', 'tired', 'of', 'things', 'that', 'surrounded', 'my', 'life,', 'I', 'like', 'see', 'pics', 'like', 'this.', 'Can', 'u', 'point', 'out', 'where', 'I', '..?', 'http://bit.ly/dPUsl']
# ['@Bkniceguy', '~', 'We', 'need', 'rap....']
# ['@cookiedorksx3', 'lmao', 'okay', 'then', 'xD', 'hahaa', 'big', 'stupiid', '?', 'well', 'i', 'agree', 'xD', 'aww', 'yaay', 'iluu', '<3']
# ['@Beadsonfire', 'welcome!', 'Anything', 'fellow', 'Etsian!']
# ['@cherrymoon', 'that', 'would', 'great.', 'thanks']
# ['@a3ofatl', 'haha', 'stupid.', 'this', 'big', 'brother.']
# ['@atanc', 'Say', 'Hi', 'everyone.', 'Ryan', '&', 'I', 'stopping', 'by', 'Stockton', 'tomorrow', 'when', 'we', 'get', 'back', 'SD.', 'Hope', 'Auntie', 'Ricky', 'doing', 'better']
# ['@bunnieface', "'s", 'cool...', "I'm", 'bout', 'mask', 'pain', 'with', 'blunts', '&', 'alcohol', '*tear*']
# ['@anca_foster', 'well', 'im', 'thinking', 'about', 'sleep', 'right', 'now', 'lol', 'tomorrow', 'i', 'start', 'html/css', 'on', 'my', 'site,', 'while', 'finishing', 'overall', 'design']
# ['@AdieJonas', 'Six', 'Flags.', 'takes', 'up', 'all', 'my', 'freaking', 'time.', 'I', 'freaking', 'hate', 'But', "I'm", 'here', 'now']
# ['@amyjbennett', "'holy", "cow'", 'what', 'did', 'this', 'me.']
# ['@AimanE2I', 'Well,', 'yea!', 'My', 'story', 'competition', 'chance', 'at', 'being', 'published,', 'so', 'yea!', 'lol']
# ['@architeuth1s', 'I', 'know', 'right!??', 'but', 'all', 'u', 'gotta', 'do', 'tell', 'me', 'naked', 'i', 'will.', 'I', 'love', 'being', 'naked!!!']
# ['@ClassicRockMag', 'Fantastic', 'album!', 'loving', 'album', 'choice']
# ['@BElanna_Torres', '@_HarryKim', 'OOC:', 'I', "can't", 'see', 'on', 'Tweetdeck,', 'or', 'on', 'web']
# ["'I", 'believe', '@annierexia', 'I', 'like', 'paper', 'mache', 'like', 'shapes', 'sly', 'always', 'so', 'fragile', 'bound', "broken'"]
# ['@beejbi', 'Hey', 'honey', 'how', 'doin??', 'haha', 'love', 'mausi']
# ['@Amarie01', 'me', 'sentiments', 'exactly!', 'made', 'us']
# ['@AtlantaJJ', 'Checking', 'back', 'sec.', 'reading', 'someone', "else's", 'thread,', 'watching', 'my', 'auction,', 'sending', 'email.', 'Multi-tasking', 'at', 'its', 'best']
# ['@bharvey80', 'i', 'love', 'fishes', "'cuz", "'re", 'sooooo', 'delicious....']
# ['@b0nnieb', 'Noted', 'noted.']
# ['@blak4ever', 'hahaha.', 'Well', "'s", '1:50', 'here.', 'LOL.', 'Dang', '@iamjonathancook.', 'Hahaha.']
# ['#rugby', '#leinster', "Rocky's", 'up', '&', 'left', '&', "isn't", 'coming', 'back', "he's", 'signed', '2yr', 'deal', 'with', 'Brumbees.', 'Ta', 'great', 'season.']
# ['@aiacobellis', 'haha', 'love', ',i', 'actaully', 'gonna', 'pick', 'that', 'one!', 'youre', 'so', 'right', 'season', '6', 'soooo', 'lame']
# ['@adamfan1million', 'haha', 'thanks!', 'i', 'think', 'i', 'might', 'buy']
# ['@AncientSoul', 'What', 'still', 'doing', 'up,', 'young', 'lady']
# ['@chloechuah', 'wow!', 'thats', 'aaweeesommeeeee']
# ['owireee']
# ['@alydenisof', 'teething', '..', 'around', '3', 'months', 'weeeeee', "'s", 'fun.', 'get', 'sleepy,', 'cranky,', 'fever', '&', 'rash', 'sometimes,', 'more', 'drool,', 'chewing']
# ['@amber_benson', 'Europe', "'s", 'breakfast', 'time.', "I'll", 'gonna', 'make', 'myself', 'coffee,', 'maybe', 'one', 'too']
# ['...Did', 'i', 'mention', '@brandyinboise', '#followfriday', '??', 'SHE', 'ROCKS!']
# ['@agentK', 'princess', 'Leia', "doesn't", 'ribbon']
# ['@BridalGlam', '@FannyLawren', "Article's", 'featured', 'on', 'pg', '32-33', 'of', 'May', 'issue.', 'I', '*think*', "'s", 'available', 'at', 'bookstores.', 'No', 'link', 'unfortunately']
# ['...', 'But', 'i', 'miss', 'my', 'shannon.', 'i', 'wuvvv', 'death']
# ['@AllStarNinja', 'He', 'did', 'laugh', 'little', 'at', 'me', 'but', 'when', 'he', 'saw', 'my', 'face', 'saw', 'how', 'I', 'glowing', 'he', 'said', 'cute']
# ['@AaronMcLellan', 'I', 'know', 'I', 'wanna', 'cry!', 'But', 'I', 'do', 'want', 'one', 'of', 'those', 'crooked', 'houses!', 'Haha']
# ["'Second", "Chance'", 'by', 'Shinedown', '&', "'Don't", 'Trust', "Me'", 'by', '30H!3', '&', "'Migraine", "Skank'", 'by', 'Gracious', 'K']
# ['@akarra', 'absolutely!']
# ['@Benjaminglass', 'I', 'meant', 'going', 'that', 'today', 'but', 'my', 'mates', 'Im', 'staying', 'with', 'Hartlepool', 'both', 'feeling', 'rough', 'so', 'stuck', 'with', 'TV']
# ['@Choylyn_Aching', 'just', 'quick', 'mention', 'by', 'Clinton', 'Sparks', 'about', "Adam's", 'statement', 'about', 'song', 'Want.', 'No', 'Adam', 'just', 'picture', 'of']
# ['@Bard_Letsinger', 'pastor', 'humorist,', 'huh?', 'Well,', 'if', 'say', 'so', '!', 'If', 'any', 'pastor', 'here', 'that', 'cute,', "I'd", 'go', 'church!', 'hahaha']
# ['@blindcripple', "I've", 'just', 'gotten', 'into', 'whole', 'hoodie', 'thing', '-', '&', 'need', 'participate', 'corruption', '&', 'bribery', 'followed', '#momentofweakness']
# ['@Alyssa_Milano', 'Virtual', 'pony', 'best', 'I', 'can', 'do....']
# ['-', 'Yet', 'another', '6am', 'studio', 'finish...but', 'great', 'results']
# ['@ceeveet', 'very', 'nice']
# ['@AFineFrenzy', 'so', 'sweet!!!', '~', 'looking', 'shockingly', 'gorgous', '~', "'frenzy'", 'shirt', '(:']
# ['@alexrk', 'haha', 'yay', 'fair', 'whoot', 'Miss', 'U<3', 'Mrs.CJBaran<3']
# ['...me', 'pin', 'my', 'bag', '&', 'silicone', 'bracelet', 'wear.']
# ['@ASinisterDuck', 'such', 'shit', 'show']
# ['I', 'kinda', 'miss', 'my', 'dad...', 'This', 'lame', 'with', 'no', 'one', 'feed', 'me', 'lil', 'pieces', 'of', 'cheese.', 'LonelyCheeseBunny.com']
# ['@crazygirlne', 'I', "don't", 'tweet', 'much', 'cuz', 'work', 'computer', 'on', 'EIS', 'Twitter.', 'So', 'I', 'only', 'tweet', 'once', 'day', '...', 'So', 'sad']
# ['@Aleenia', 'premium', 'conversions', 'disabled?', 'I', 'sent', 'ticket', 'told', 'me', 'no.i', 'need', 'unseal', 'my', 'items', 'exp.I', 'still', '55', 'hours', 'bronze']
# ['@asavinggrace', "I'm", 'about', 'watch', 'right', 'now,', 'thanks', 'telling', 'me']
# ['@caitlinmulvey.', 'Why', 'so', 'sad', '?']
# ['@AnaSerrano', 'Hey', 'girl!', 'I', 'just', 'same', 'feeling!', 'Sweet', 'sweet', 'dreams,', "I'll", 'see', 'when', 'wake', 'up']
# ['@cami_lou', 'I', "can't", 'ever', 'catch', 'one...', "'re", 'too', 'smart.', 'I', 'need', 'go', 'hunting', 'school', 'dogs', 'somewhere.']
# ['@crazy_gurl214', 'I', 'just', 'empty', 'pockets']
# ['@baconpops', 'Hate', 'say', ',', 'but', 'friend', 'of', 'mine', 'said', 'he', 'got', 'some', 'BaconPops', "wasn't", 'impressed.', 'Too', 'bad,', "'s", 'great', 'concept!']
# ['@bunnykins2', "'re", 'welcome']
# ...
# ['@Boy_Kill_Boy', 'oh', 'ryan', 'im', 'soo', 'sorry', 'my', 'internet', 'connection', 'sucks', 'whose', 'no', '1', 'btw', '?']
# ['@chairiste', 'Wish', 'I', 'could', 'searching', 'with']
# ['@caseeyrae', 'aww', "i'd", 'come', 'bondi', 'but', 'im', 'kinda', 'going', 'airport']
# ['@crittersize', 'Very', 'cute', 'profil', 'pic...', 'will', 'check', 'out', 'website', 'soon!']
# ['@7_7', 'yes', 'but', 'ugly']
# ['@AlanG123', 'no', 'worries...', 'happy', 'help.']
# ['@abbyryder', 'Heh', 'me', 'both.', 'I', 'needs', 'me', 'Blurr..Tesco', 'all', 'sold', 'out!!!', 'Wish', 'would', 'make', "'Snarl'", '&', 'Sludge', 'too']
# ['@chabling', 'okay', 'babe...nomore', 'torture', 'on', 'twitter', 'pleaseeeee!!!', 'Yall', 'got', 'us', 'this', 'year..now', 'I', 'gotta', 'watch', 'yall', 'parade', 'cry', '2morrow..']
# ['@abczoomom', 'I', 'find', 'that', 'I', 'indeed', 'going', 'town', 'today']
# ['@AcetheActor', 'I', 'think', 'gonig', 'with', 'any', 'girl', 'mall', 'bad', 'idea', 'dude']
# ['@asotfan', 'Its', 'all', 'good', "We're", 'here', 'share', 'love', 'trance!!', '#asot400']
# ['@BawldGuy', 'that', 'post', 'hit', 'spot.', 'How', 'can', 'beat', "'self", 'righteous', "dung'"]
# ['@AleeVee', 'qualifying', 'loan.', 'Without', 'loan', 'he', "can't", 'get', 'car.', 'But', "we'll", 'see.']
# ["'Dear", 'John,', 'I', 'freaking', 'MESS!', 'I', 'may', 'need', 'seek', 'professional', 'help', 'soon...', 'Signed,', "Bedroom'"]
# ['@__stephanielynn', 'LOL', 'tell', 'me', 'how', 'but', 'dont', 'ruin', 'too', 'much,', 'i', 'supposed', 'go', 'see', 'tonight', 'poor', 'kristen']
# ['@__specialK', '@Lyrical_Gangsta', '@wishdreamhope', 'whoever', ',', 'super', 'awesome!', 'I', 'love', 'music', 'random', 'thoughts!', 'Stick', 'around!!']
# ['@AshleyNiles', "I'm", 'sorry,', 'sucks']
# ['@akashasoap', 'yeah', 'dont', 'worry,', 'will', 'do', '!!really', 'sooon']
# ['@andytpowell', "'re", 'welcome!']
# ['@AffiliateMark', 'i', 'know,', 'wally', 'rough', 'go', 'but', 'who', 'hot', 'night?', 'only', 'delonte.', 'which', 'does', 'not', 'equal', 'win.']
# ['@_Garbage_', '-', 'Watched', '&D', 'theatres,', '120', 'INR']
# ['@', 'pooll', 'w/', 'ja9,', 'txt', 'AdamLivesOn']
# ['@atfsteve', 'Ironically,', 'Lola', 'ate', 'one', 'of', 'my', 'favorite', 'green', 'Adidas', 'shoes', 'today']
# ['@AlexAllTimeLow', 'aww', 'como', 'brazill', 'alexx']
# ['@AllyBingham', 'specifically', 'went', 'on', 'facebook', '.', 'feel', 'special,', 'because']
# ['@awatrous', 'hey,', "what's", 'up?']
# ['@AClockworkToad', 'I', 'told', 'TTT!']
# ['@aplusk', 'I', 'would', 'love', 'this', 'doll..beautiful!', 'She', 'so', 'realistic', 'I', 'love', 'long', 'dark', 'hair.']
# ['@BuckyBug', 'I', 'know', 'haha', 'thats', 'because', 'I', 'live', 'on', 'hehe.']
# ['@ashizbadd', 'lmao', 'I', 'know', 'my', 'own', 'bf', "don't", 'wanna', 'touch', 'me', 'bday', '2mar!', 'big', '1-8']
# ['@AlexJayson', 'idk', 'but', 'makes', 'me', 'sad', 'haha', 'jk', 'but', 'i', 'reallly', 'no', 'idea', 'tho']
# ['@Coodieranks', 'now', 'rumor', 'columbus', 'playing', 'other', 'team', 'but', 'hiding', 'jersey...but', 'not', 'idris!!!', 'Nooooooooo']
# ['@AnnReyWil', 'Usually', 'I', 'think', 'too', 'much', 'of', 'good', 'thing', 'fabulous!']
# ['@Classicgarage', 'Z1', '900,twin', 'webers,yosi', 'kit,', 'flew']
# ['@AnnePrecious', 'hey', 'pre!!', 'how', '?', 'hehehee!', 'fun', 'magtwitter', 'noh?', 'hehehe!']
# ['@ABIBAN', 'do', 'want', 'me', 'split', 'up?', 'i', 'good', 'at', 'crafty', 'plans', 'like', 'this']
# ['@', 'sis', 'house', 'relaxing']
# ['@aprilfoster', '-', 'Thanks', 'April']
# ['@Akelaa', 'haha.', 'unfortunately', "I'm", 'not', 'talking', 'about', 'me', 'personally...of', 'course', "I'd", 'use', 'twitter']
# ['@chamillionaire', 'lol.', 'Someone', 'brought', 'stash', 'mag', 'party', 'proof', 'security', 'he', 'rapper']
# ['@', 'hpapi', 'woah', 'u', 'gud', 'long', 'u', 'dnt', 'hav', 'boosie', 'fade', 'or', 'plies', 'receiding', 'hairline', '(He(<)ArT)']
# ['@clubjuicy', 'dammit!', 'I', 'told', 'send', 'Im', 'sorry', 'man...', "I'm", 'excited', 'see', ',', 'send', 'my', 'way...']
# ['@amandaodt', 'password', 'ODT', 'thread!', 'Feel', 'free', 'help!']
# ['our', 'plans', 'changed', '&', 'we', "aren't", 'able', 'see', 'Transforers', 'tonight!!', 'Sorry', '@justcherie', '&@brittany_ko', 'make', 'up', '!!']
# ['>>>', 'Mood', '=', 'Crying', 'boo', 'hoo']
# ['@CreativeSoul', 'I', 'always', 'specific', 'with', 'my', 'wife', 'when', 'I', 'want', 'go', '*Apple*', 'store', 'not', '*Mac*', 'store.', 'No', 'makeup', 'buying!']
# ['@16_MileyCyrus', 'Monday', 'Night', 'At', '9Pm', '(On', 'MTV', 'One)', '(Y)', '=D']
# ['@cristina_dr', 'I', 'MISS', 'SO', 'MUCH.', 'Move', 'back', 'Lgv', 'nga!', 'We', 'better', 'classmates', 'next', 'year.', ':|']
# ['#unfollowdiddy', 'because', 'bottlerockets', 'he', 'sold', 'me', "didn't", 'go', 'anywhere']
# ['@beverly', 'amazing!', 'like', 'softer', 'banana', 'bread', 'covered', 'peanut', 'butter.', 'We', 'also', 'ended', 'up', 'drizzling', 'chocolate', 'syrup', 'on', ',', 'too!']
# ['@ClaireS16', 'thank']
# ['@chingdynasty', 'woah..', "that's", 'good', 'news..', 'spammers', 'should', 'get', 'life..', 'lol.']
# ['@4barrys', 'Thanks', 'Scoot-Scoot!', 'I', 'so', 'lucky', 'my', "'neighbor'...", 'coolest', 'one', 'office!']
# ['@angstmann', 'Yep,', 'same', 'here.', 'Apologies', 'late', 'reply;', "I've", 'been', 'twitterless', 'until', 'now.', 'Gorgeous', 'weather', 'London', 'but', 'work', 'looms']
# ['@babblingbrookie', 'Try', 'being', 'AZ', 'again', 'brooke,', 'Omg', 'cant', 'even', 'outside', 'less', 'than', 'minute', 'getting', 'neck', 'burned.']
# ['@cardsforheroes', 'I', 'uploaded', 'mine', 'too,', 'but', "doesn't", 'blink', 'I', 'tried', 'few', 'times', 'still', 'no', 'luck.']
# ['@BrandyWandLover', 'Haha', 'aww', 'bless,', 'tortoises', 'wierd', 'eh,', 'but', 'harmless', 'i', 'held', 'that', 'lizzard', 'just', 'still', 'whole', 'time!', 'wierd!']
# ['@buguletzu', 'thanks']
# ['@', 'thanks', 'babe', 'i', 'certainly', 'will']
# ['@BackpackingDad', 'Awwwwwwww...that', 'one', 'good-looking', 'baby!', 'Great', 'news', 'wake', 'up', '.', 'Congratulations']
# ["'people", 'change,', 'life', 'changes,', 'friends', 'change,', 'but', 'bud', 'just', 'gotta', 'move', "on.'-demi", "lovato.'s", 'like', 'she', 'knows', 'whats', 'going', 'on', 'right', 'now.']
# ['@calvinharris', 'never', 'does']
# ['@bridewithbroom', 'LOL', 'Glow', 'Worm!!', 'Omg', 'I', 'wanted', 'one', 'of', 'those', 'but', 'never', 'got', 'one', 'Im', 'waiting', "'My", 'Pet', "Monster'", 'live-action', 'film', 'myself.']
# ['@airaxDlovesdemi', 'yes', 'please', '?']
# ['@BerlianAyudya', 'my', 'little', 'lappy', 'runs', 'both', 'Linux', 'windows,', 'windows', 'always', 'issues', 'with']
# ['@ACiccone', 'Not', 'yet!', 'But', 'looking.']
# ['@anjooooo', 'WHAT', 'F!!!!', 'Did', 'get', 'broken?']
# ['@_EpicFail', 'my', 'friend', 'who', 'camera', 'obsession', 'will', 'come', 'so', 'sure', "'ll", 'get', 'some', 'even', 'some', 'taken', 'especially']
# ["'Dude", 'u', 'naked', 'pic', 'of', 'Jen', 'Aniston', 'on', 'ur', 'site...', 'im', 'not', 'that', 'kinda', 'grl.', 'sorry', "'", 'just', 'received', 'this', 'interesting', 'shout', 'on', 'lastfm', 'haha']
# ['@Caps_Girl', 'LOL...', 'should', 'totally', 'shirts', 'made', 'up', 'with', 'that...', 'maybe', 'sell', "'em", 'on', 'CafePress', 'or', 'something.']
# ['-', 'My', 'sister', "Janet's", 'friend', 'Julie', 'passed', 'this', 'morning', 'cancer,', 'please', 'say', 'prayer', 'family.', 'She', 'only', '39', '-', 'so', 'very', 'sad!']
# ['@AlanCarr', 'McFly', '-', 'Falling', 'love', 'I', 'kind', 'of', 'video']
# ['@Alyssa_Milano', 'Good', 'evening', 'truly', 'very', 'inspiring', 'woman...plus', 'dogs', 'adorable!!!', 'How', 'doing?', 'x']
# ['@BloggingLance', 'thank', 'but', 'doesnt', 'work', 'iPhone', 'been', 'done', 'that', 'no', 'flash', 'with', 'this', 'baby']
# ['@bubblegarm', 'i', 'tried', 'that', 'yday', 'failed', 'miserably...LOL!', 'i', 'no', 'willpower!', "'s", 'supposed', 'clean', 'system', 'though!xx']
# ['@bboyvizion', 'I', 'smashed', 'amandas', 'by', 'accident', 'donate', 'mine', 'make', 'up']
# ['@agentkebong', 'who', "doesn't", 'oh', 'man', 'I', 'LOOOOVE', 'THEEEM', '!']
# ['@antothedrew', "Don't", 'hate', 'me', 'we', 'all', 'flaws', 'haha!']
# ['@BrittanyHauff', 'Yeah,', "i'm", 'sick', 'huhu..', 'I', 'wanna', 'see', 'perform', 'together']
# ['@androidtomato', 'oh', 'renting', '10', 'inch', 'hero', 'waiting', 'mail.']
# ['@crystalbutterfl', 'That', 'one', 'deep', 'gash', 'doozy,', 'so', 'yeah,', 'still', 'mending,', 'but', 'every', 'day', 'better']
# ['@bolly47', 'tweet', 'just', 'included', 'Longest', 'Poem', 'World', 'www.longestpoemintheworld.com/tweet/12086/']
# ['@c0074gd', 'tell', 'me', 'about', '.', 'Im', 'on', 'til', '6', 'tonight', 'Im', 'abt', 'grab', 'me', '2nd', 'one!']
# ['@8bithack', 'Sadly,', 'I', 'really', 'looking', 'forward', 'Crimson', 'Skies.', "'s", 'also', "d/l'd", 'orig.', 'games', 'that', "don't", 'work.']
# ['I', 'love', 'so', 'much', 'but', 'our', 'views', 'so', 'different.']
# ['@Cineris', "'s", 'tough', 'cut.', 'I', 'amazong', 'stylist.', ';)', 'I', 'actually', 'brought', 'up', 'even', 'shorter', 'my', 'Triple', 'Word', 'Score', 'set.']
# ['@ACC1987fans', 'Yeah', "that's", 'fine,', 'go', 'ahead!']
# ['@Amanda____', 'im', 'going', 'call', 'noww']
# ['@AprilRPengilly', 'Do', 'like', 'over', 'London?', "That's", 'so', 'cool', 'how', 'model', 'badass', 'mc!', 'must', 'having', 'great', 'time!']
# ['@akolb2', 'Hey', 'Ashlie,', 'I', 'just', 'follow', 'someone', 'with', 'my', 'own', 'last', 'name', 'Nice', 'meet', '.', 'great', 'day']
# ['@ashmabash', 'take', 'me', 'this', 'time!']
# ['@corieography', 'ahh', "I'd", 'imagine.', 'Gotta', 'do', 'those', 'stairs', 'squats']
# ['@babyblackbear', 'yes!', "I'm", 'ready.', 'At', 'same', 'time', 'again?']
# ['@blaise_f', 'baahhh', 'I', 'want', 'thai', 'food!', "I'm", 'jealous']
# ["'Oldtimers,", 'weekends,', 'airplane', 'landings', 'alike.', 'If', 'can', 'walk', ',', "'re", "successful'", '-', 'Casey', 'Stengel', 'Morning', 'all!']
# ['@AC_1', 'Happy', 'Birthday', 'Andrew!']
# ['@caseymariex', 'Hehe', 'I', 'know', '....', 'I', 'wish', 'I', 'could', 'go', 'those', 'shows', 'with', "y'all"]
# ['@_meeks_', 'i', 'left', 'my', 'house', 'too', 'late', 'get', '.']
# ['@cascandar', "I'm", 'more', 'of', 'dog', 'person', 'myself.', 'Cats', 'always', 'seem', 'like', 'something', 'better', 'do.', 'Plus', "I'm", 'alergic']
# ['@Ausiray', 'Looks', 'like', 'great', 'product!', 'How', 'guys?']
# ['@angie_BBY', 'oh', 'lucky!!', 'its', 'like', 'FREEZING', 'heree']
# ['@___radioactivex', 'i', 'always', 'get', 'sony', 'ericssons..', 'pretty', 'good']
# ['@aplusk', 'what', 'does', 'ding', 'dong', 'ditch', 'mean?', 'sorry', 'now', 'knowing.']
# ['#myweakness', 'too', 'loving', '...i', 'always', 'let', 'negative', 'people', 'into', 'my', 'life']
# ['@accesshollywood', "Farrah's", 'Story', 'very', 'sad']
# ['@alliterating', 'Sunday', 'good', 'mall?']
# ["...I'm", 'just', 'helping', 'along', 'with', 'this', 'twitter', 'putting', 'vids', 'on', 'youtube,', 'cos', 'I', 'really', 'wanna', 'see', 'Ellen', 'come', 'Oz']
# ['@Beverleyknight', 'all', 'good', 'thanks,', 'hope', 'all', 'good', 'time.']
# ['@berlins', "that's", 'what', 'i', 'meant,', 'yes']
# ['@alisabirks', 'Thank', 'kind', '#followfriday!', 'good', 'weekend']
# ['@AlexislovesJB', "I'm", 'too', 'un-tired', 'silly', 'today', 'Haha', 'we', 'just', 'delirious', 'on', 'phone', 'last', 'night']
# ['@Chiggady', 'ur', 'bbm', 'message', 'hurts', 'my', 'feelings.', 'lol']
# ['@AIRasheville', 'Good', 'point.', 'Thanks', 'being', 'me.']
# ['I', 'want', 'freaking', 'puppy', 'now!', 'cute', 'little', 'black', 'yorkshire', 'terrier.']
# ['@antgalvin', 'Hate', 'that']
# ['@archnix', 'hay', 'nku,', 'cnbi', 'mu', 'pa.', 'Haha.', 'Grabe!', 'I', 'almost', 'fell', 'my', 'seat', 'when', 'i', 'saw', 'lol.', 'Sayang', 'nga', 'lang', 'kc', 'dq', 'nkta', 'c', 'archie.', 'pro', 'ok', '...']
# ['*yucks*', 'what', 'big', 'cockroach', 'doing', '@', 'B1', 'wisma', 'Toastbox..']
# ['-', '@serialseb', 'Always', 'thought', 'time', 'estimates', 'should', 'use', "'value", 'of', 'Pi', "rule'", '(x', '3.14).', 'Only', 'exception', 'being', "'Pi", 'squared', "rule'."]
# ['@asmaazizanhm', "that's", 'good,', 'pandai2', 'sja', 'manage', 'time', 'keh']
# ['@cathrynbray', 'sorry']
# ['@ColorblindFish', 'Man!', 'guys', 'killing', 'me!', 'just', 'tease!', 'But', 'I', 'like', '!', 'Thanks', 'Fish!', 'Andrea']
# ['@211me', 'awwww', 'no', "don't", 'leave', 'us']
# ['@AlanCarr', 'shuuupberb', 'last', 'night-', 'well', 'done']
# ["'name", "please'", "'Dawson,", 'Rose', "Dawson'", 'aweee', 'sooo', 'cute', 'i', 'fcking', 'love', 'this', 'movie!!!', 'XD']
# ['@BabyLuu', 'not', 'if', "'s", '.', 'ahahaha', 'jk.', 'missss']
# ['...', 'much', 'i', 'like', 'celebrities...following', 'ppl', 'u', 'dnt', 'know', '&', 'dnt', 'respond', 'pretty', 'boring']
# ['@AnthxnyJE', 'Thanks.', 'So,', 'doesnt', 'exist', 'program', 'backup', 'all', 'our', 'downloads?', '.', 'Just', 'All', 'again']
# ['@Aur1', 'Saw', 'tweets', 'I', 'just', 'wanted', 'say', 'hi!', "I'm", 'pulling', 'all-nighter', 'finish', 'some', 'work.', 'great', 'day,', 'good!']
# ['@Alvaroyanez', 'thank', 'haha', 'we', 'should', 'go', 'all', 'hangout', 'again', 'ha', "let's", 'go', 'get', 'get', 'something', 'eat!']
# ['@BinaryOffbeat', 'I', 'wanna', 'do', 'something', 'too.', 'Pero', "I'm", 'stuck', 'babysitting', 'tonight']
# ["'I", 'know', 'what', 'like,', 'I', 'know', 'what', 'think,', 'not', 'afraid', 'stare', 'down', 'until', "blink.'", "I've", 'got', 'nerve', '#Miley', 'Cyrus']
# ['@CinnamonCloud', 'Nope', 'very', 'upset', 'I', 'like', 'actor!']
# ['i', 'still', 'uber', 'sick', '(lol,', 'FEVERISH', 'AT', 'LAB', 'TODAY!)', 'my', 'lab', 'report', 'barely', 'progressing.', 'FML!!!!!', '!!!!!!']
# ['@Andys184', 'shes', 'connecticut', 'all', 'weekend', 'son.']
# ['@bsneed23', 'oh', 'what', 'day!', "Let's", 'see,', 'I', 'lost', 'my', 'keys,', 'dug', 'thru', 'trash', '&', 'finally', 'called', 'locksmith.', 'Having', 'one', 'of', 'thoooose', 'days']
# ['@Bookfoolery', 'Oh', 'I', 'saw', '!', "I'd", 'been', 'watching', ',', 'since', 'I', 'posted', 'those', 'just', '.', 'Thank', 'kind', 'words']
# ['@ChuckNerd', 'Why', 'Josh', 'Schwartz?', 'We', 'talking', 'about', 'banana', 'pancakes', 'earlier', 'because', 'song', 'stuck', 'my', 'head...', 'made', 'me', 'hungry!']
# ['@Axika', 'http://twitpic.com/6qh41', '-', 'here', 'Thailand...we', 'just', 'got', "'baby", "panda'", '...!!!']
# ['@Bffleck', 'When', 'next', 'film', 'will', 'working', 'on?', 'Why', 'does', 'wife', 'twitt', 'account', '!', 'Love', 'too!', 'Blessings!']
# ['@antgalvin', 'not', 'shocking', '-', 'Kilkenny', 'need', 'bit', 'of', 'beating', 'every', 'so', 'often']
# ['I', 'miss', 'u', 'mum', 'So', 'much.', 'I', 'wish', 'u', 'here', 'because', 'u', 'r', 'one', 'I', 'would', 'talking', 'about', 'Andrew', 'right', 'now']
# ['@CTerry1985', "That's", 'thing;', 'new', 'raft', 'of', 'Star', 'Wars', 'films', 'just', 'raft', 'of', '#EpicFail', 's']
# ['@Crow74', 'I', 'know.', 'I', 'feel', 'I', 'got', 'shot', 'on', 'side', 'of', 'my', 'head.', 'Hurts', 'down', 'my', 'jaw,', 'too.']
# ['@civlee', 'thankyou', 'so', 'much', '!', 'wonderful', 'weekend!']
# ['@applecritics', 'Get', '100', 'followers', 'day', 'using', 'www.tweeterfollow.com', 'Once', 'add', 'everyone', 'on', 'train', 'or', 'pay', 'vip']
# ["'take", 'me', 'with', 'I', 'start', 'miss', "'"]
# ['@Bloodywind', 'yeah', 'I', 'ate', '.', 'too', 'tired', '&', 'hungry', 'complain']
# ['@britneyxvideo', '@TammiByrd', '@4shZoJ', 'welcome', '2', 'our', 'lovely', 'twitt', 'fam...thanx', '4', 'joinin', 'us..&', 'dont', 'b', 'stranger']
# ['@ancesmulles', 'so.', 'when?']
# ['@99seats', "'ll", 'get', 'hang', 'of', '!']
# ['@Barcardicider', 'CONGRATS', 'ON', 'JOB!!!!', 'Knew', "'d", 'get', '!', '\\o/', '\\o/', '\\o/', '\\o/', '\\o/', '\\o/']
# ['@adlevocine', 'thank']
# ['@BadPony', 'Way', 'kick', 'me?']
# ['@aditya', 'this', 'account', 'may', 'talking', 'bit...', "I'm", 'testing', 'stuffs']
# ['@chead', 'same....', 'hero', 'hottttt.', 'too', 'bad', 'its', 'gsm']
# ['@__oddsocks', 'exam', 'morning']
# ['@amarie226', "we're", 'doin', 'pretty', 'good']

# %%
#Normalize features
ft = pd.concat(features,1)
ft.to_csv('../data/features.csv')
#Make Combined database
normedFeats = pd.DataFrame(preprocessing.scale(ft))
dataFrame = pd.DataFrame(labels)
finalFeats = dataFrame.join(normedFeats)

# %%
#save to file for SVM learning
finalFeats.to_csv(featF, index=False)

# %%
tw = "@cpuclub what the hell mike died???? Fuck man I always played for that guy in denver. Such a generous and kind dude. Rip "
tw = modify(tw)
print(tw,len(tw))
features = {i:f(tw) for i,f in feats.items()}#ma
print(features)
# Out:
# @cpuclub what the hell mike died???? Fuck man I always played for that guy in denver. Such a generous and kind dude. Rip 120
# ['@cpuclub', 'what', 'hell', 'mike', 'died????', 'Fuck', 'man', 'I', 'always', 'played', 'that', 'guy', 'denver.', 'Such', 'generous', 'kind', 'dude.', 'Rip']
# {'0': 120, '1': 23, '2': 113, '3': 18, '4': 0, '5': 0}
